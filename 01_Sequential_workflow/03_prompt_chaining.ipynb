# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

# %%
class BlogState(TypedDict):
    
    title : str
    outline : str
    content : str

# %%
def create_outline(state : BlogState) -> BlogState:
    
    # fetch title
    title = state['title']
    
    # call llm gen outline
    prompt = f"Generate a outline for a blog on the topic {title}"
    outline = model.invoke(prompt).content
    
    
    # update state
    state['outline'] = outline
    
    return state

# %%
def create_blog(state : BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']
    
    
    prompt = f"Write a detailed blog on the title {title} using the following outline \n {outline}"
    
    
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node("create_outline", create_outline)
graph.add_node("create_blog", create_blog)


# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)


workflow = graph.compile()

# %%
intial_state = {'title' : 'Rise of Ai in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of Ai in India', 'outline': 'Here\'s an outline for a blog post on the "Rise of AI in India," designed to be engaging, informative, and well-structured.\n\n---\n\n## Blog Post Outline: The AI Awakening: Charting the Rise of Artificial Intelligence in India\n\n### I. Title Options (Choose one or combine elements)\n*   The AI Awakening: Charting the Rise of Artificial Intelligence in India\n*   India\'s AI Revolution: From Niche to National Priority\n*   The Next Frontier: How India is Embracing the Power of AI\n*   Decoding India\'s AI Boom: Opportunities, Challenges, and the Road Ahead\n\n### II. Introduction (Approx. 150-200 words)\n*   **A. Hook:** Start with a compelling statistic or a thought-provoking statement about the global AI revolution and its transformative power.\n    *   *Example:* "The world is in the throes of an AI revolution, and at its heart, a vibrant nation is rapidly emerging as a formidable player: India."\n*   **B. Context:** Briefly set the stage – why India is uniquely positioned for AI growth (e.g., large talent pool, digital transformation, unique problems to solve).\n*   **C. Thesis Statement:** State the blog\'s main argument – India is experiencing a significant and multi-faceted rise in AI adoption and innovation, driven by various factors and poised for transformative impact.\n*   **D. What Readers Will Learn:** Briefly outline the key areas the blog will cover (e.g., drivers, applications, challenges, future outlook).\n\n### III. The Driving Forces Behind India\'s AI Boom (Approx. 300-400 words)\n*   **A. Government Initiatives & Policy Support:**\n    *   "Digital India" and "Make in India" campaigns laying the groundwork.\n    *   NITI Aayog\'s "National Strategy for Artificial Intelligence" (AI for All).\n    *   Focus on creating data infrastructure and promoting R&D.\n    *   Role of state governments in fostering AI hubs.\n*   **B. A Robust Talent Pool:**\n    *   India\'s massive base of STEM graduates and IT professionals.\n    *   Growing number of data scientists, machine learning engineers.\n    *   Upskilling initiatives and academic programs in AI/ML.\n*   **C. Thriving Startup Ecosystem & Investment:**\n    *   Explosion of AI-focused startups across various sectors.\n    *   Increased venture capital and private equity investment in AI.\n    *   Incubators and accelerators supporting AI innovation.\n*   **D. Massive Digital Adoption & Data Availability:**\n    *   High internet penetration (Jio effect) and smartphone usage.\n    *   Aadhaar, UPI, and other public digital infrastructure creating vast datasets.\n    *   Digital-first consumer base driving demand for AI-powered solutions.\n*   **E. Global Tech Giants & R&D Centers:**\n    *   Presence of major international tech companies (Google, Microsoft, IBM, Amazon) setting up AI research and development centers in India.\n    *   Collaboration with Indian universities and startups.\n\n### IV. AI in Action: Key Sectors & Applications (Approx. 300-400 words)\n*   **A. Healthcare:**\n    *   Diagnostics (e.g., AI for radiology, pathology).\n    *   Drug discovery and personalized medicine.\n    *   Telemedicine and remote patient monitoring.\n    *   *Example:* AI tools for early detection of diabetic retinopathy.\n*   **B. Finance & Banking (FinTech):**\n    *   Fraud detection and risk assessment.\n    *   Personalized banking services and credit scoring.\n    *   Algorithmic trading and investment advisory.\n    *   Chatbots for customer service.\n*   **C. Agriculture (AgriTech):**\n    *   Crop yield prediction and pest detection.\n    *   Weather forecasting and precision farming.\n    *   Supply chain optimization.\n    *   *Example:* AI-powered drones for crop health monitoring.\n*   **D. Education (EdTech):**\n    *   Personalized learning paths and adaptive content.\n    *   Automated grading and feedback.\n    *   Intelligent tutoring systems.\n*   **E. E-commerce & Retail:**\n    *   Personalized recom ...

# %%
print(final_state['outline'])
# Out:
# Here's an outline for a blog post on the "Rise of AI in India," designed to be engaging, informative, and well-structured.
#
# ---
#
# ## Blog Post Outline: The AI Awakening: Charting the Rise of Artificial Intelligence in India
#
# ### I. Title Options (Choose one or combine elements)
# *   The AI Awakening: Charting the Rise of Artificial Intelligence in India
# *   India's AI Revolution: From Niche to National Priority
# *   The Next Frontier: How India is Embracing the Power of AI
# *   Decoding India's AI Boom: Opportunities, Challenges, and the Road Ahead
#
# ### II. Introduction (Approx. 150-200 words)
# *   **A. Hook:** Start with a compelling statistic or a thought-provoking statement about the global AI revolution and its transformative power.
#     *   *Example:* "The world is in the throes of an AI revolution, and at its heart, a vibrant nation is rapidly emerging as a formidable player: India."
# *   **B. Context:** Briefly set the stage – why India is uniquely positioned for AI growth (e.g., large talent pool, digital transformation, unique problems to solve).
# *   **C. Thesis Statement:** State the blog's main argument – India is experiencing a significant and multi-faceted rise in AI adoption and innovation, driven by various factors and poised for transformative impact.
# *   **D. What Readers Will Learn:** Briefly outline the key areas the blog will cover (e.g., drivers, applications, challenges, future outlook).
#
# ### III. The Driving Forces Behind India's AI Boom (Approx. 300-400 words)
# *   **A. Government Initiatives & Policy Support:**
#     *   "Digital India" and "Make in India" campaigns laying the groundwork.
#     *   NITI Aayog's "National Strategy for Artificial Intelligence" (AI for All).
#     *   Focus on creating data infrastructure and promoting R&D.
#     *   Role of state governments in fostering AI hubs.
# *   **B. A Robust Talent Pool:**
#     *   India's massive base of STEM graduates and IT professionals.
#     *   Growing number of data scientists, machine learning engineers.
#     *   Upskilling initiatives and academic programs in AI/ML.
# *   **C. Thriving Startup Ecosystem & Investment:**
#     *   Explosion of AI-focused startups across various sectors.
#     *   Increased venture capital and private equity investment in AI.
#     *   Incubators and accelerators supporting AI innovation.
# *   **D. Massive Digital Adoption & Data Availability:**
#     *   High internet penetration (Jio effect) and smartphone usage.
#     *   Aadhaar, UPI, and other public digital infrastructure creating vast datasets.
#     *   Digital-first consumer base driving demand for AI-powered solutions.
# *   **E. Global Tech Giants & R&D Centers:**
#     *   Presence of major international tech companies (Google, Microsoft, IBM, Amazon) setting up AI research and development centers in India.
#     *   Collaboration with Indian universities and startups.
#
# ### IV. AI in Action: Key Sectors & Applications (Approx. 300-400 words)
# *   **A. Healthcare:**
#     *   Diagnostics (e.g., AI for radiology, pathology).
#     *   Drug discovery and personalized medicine.
#     *   Telemedicine and remote patient monitoring.
#     *   *Example:* AI tools for early detection of diabetic retinopathy.
# *   **B. Finance & Banking (FinTech):**
#     *   Fraud detection and risk assessment.
#     *   Personalized banking services and credit scoring.
#     *   Algorithmic trading and investment advisory.
#     *   Chatbots for customer service.
# *   **C. Agriculture (AgriTech):**
#     *   Crop yield prediction and pest detection.
#     *   Weather forecasting and precision farming.
#     *   Supply chain optimization.
#     *   *Example:* AI-powered drones for crop health monitoring.
# *   **D. Education (EdTech):**
#     *   Personalized learning paths and adaptive content.
#     *   Automated grading and feedback.
#     *   Intelligent tutoring systems.
# *   **E. E-commerce & Retail:**
#     *   Personalized recommendations and customer experience.
#     *   Supply chain and inventory management.
#     *   Chatbots and virtual assistants.
# *   **F. Public Services & Governance:**
#     *   Smart cities initiatives.
#     *   Optimizing public transport and traffic management.
#     *   Disaster management and resource allocation.
# *   **G. Unique Indian Innovations:**
#     *   Focus on multilingual AI and voice interfaces (addressing linguistic diversity).
#     *   Developing AI solutions for "Bharat" (rural and semi-urban India) problems.
#
# ### V. Challenges and Considerations (Approx. 200-250 words)
# *   **A. Data Privacy and Security:** Ensuring robust frameworks for handling vast amounts of personal data.
# *   **B. Ethical AI and Bias:** Addressing algorithmic bias, fairness, and transparency in AI systems.
# *   **C. Job Displacement and Reskilling:** The need for workforce retraining and adapting to evolving job markets.
# *   **D. Infrastructure Gaps:** Bridging the digital divide in rural areas, ensuring access to high-speed internet and computing power.
# *   **E. Funding for Deep Tech Research:** Encouraging more investment in fundamental AI research, not just applications.
# *   **F. Regulatory Framework:** Developing comprehensive and agile regulations that foster innovation while ensuring safety and accountability.
#
# ### VI. The Road Ahead: India's AI Future (Approx. 150-200 words)
# *   **A. Global AI Hub Potential:** India's ambition to become a world leader in AI innovation and deployment.
# *   **B. Focus on Responsible AI:** Emphasizing ethical development and deployment for societal good.
# *   **C. Continued Investment:** In R&D, skill development, and cross-sector collaboration.
# *   **D. Impact on Economy and Society:** How AI can drive economic growth, improve public services, and enhance quality of life.
# *   **E. International Collaborations:** Role of partnerships with global AI leaders and organizations.
#
# ### VII. Conclusion (Approx. 100-150 words)
# *   **A. Recap:** Briefly summarize the key drivers, applications, and the immense potential of AI in India.
# *   **B. Reiterate Thesis:** Reinforce the idea that India's AI journey is significant and transformative.
# *   **C. Final Thought/Call to Action:** End with an optimistic outlook and a forward-looking statement about India's role in shaping the global AI landscape.
#     *   *Example:* "As India continues to innovate and integrate AI across its vast and diverse landscape, its journey promises not only to redefine its own future but also to offer a compelling blueprint for how emerging economies can responsibly harness the power of artificial intelligence for collective prosperity."
# *   **D. Engage Readers:** "What are your thoughts on India's AI trajectory? Share your insights in the comments below!"
#
# ---

# %%
print(final_state['content'])
# Out:
# # The AI Awakening: Charting the Rise of Artificial Intelligence in India
#
# The world is in the throes of an AI revolution, a technological tsunami poised to reshape industries, economies, and societies. At its heart, a vibrant and rapidly emerging nation is establishing itself as a formidable player: India. With its unique blend of a vast digital-first population, an immense talent pool, and a pressing need for scalable solutions, India is not just observing the global AI wave; it's actively riding it, transforming from a technology adopter to a significant innovator. This blog post delves into the multifaceted rise of Artificial Intelligence in India, exploring the powerful forces driving its growth, the diverse sectors it’s impacting, the critical challenges that need addressing, and the ambitious vision for its future. Prepare to decode India's AI boom – its opportunities, challenges, and the exciting road ahead.
#
# ## The Driving Forces Behind India's AI Boom
#
# India's journey towards becoming a global AI powerhouse is propelled by a confluence of strategic initiatives, intrinsic strengths, and a burgeoning digital ecosystem.
#
# **A. Government Initiatives & Policy Support:** The groundwork for India's AI ascent was meticulously laid by ambitious government programs. "Digital India" and "Make in India" campaigns fostered a digital-first mindset and encouraged domestic innovation. Crucially, NITI Aayog's "National Strategy for Artificial Intelligence" (colloquially known as "AI for All") provided a comprehensive roadmap, focusing on leveraging AI for inclusive growth across key sectors while promoting research and development. State governments, recognizing AI's potential, are also actively fostering AI hubs and incubators, creating a conducive environment for innovation.
#
# **B. A Robust Talent Pool:** Perhaps India's most significant asset is its massive base of STEM graduates and IT professionals. The nation churns out millions of engineers annually, leading to a rapidly growing number of data scientists, machine learning engineers, and AI researchers. Universities and private institutions are responding to this demand with specialized academic programs and upskilling initiatives, ensuring a continuous supply of skilled personnel ready to tackle complex AI challenges.
#
# **C. Thriving Startup Ecosystem & Investment:** India's entrepreneurial spirit has found a new frontier in AI. The country is witnessing an explosion of AI-focused startups across various sectors, from healthcare to finance. This burgeoning ecosystem is fueled by increased venture capital and private equity investment, with both domestic and international funds recognizing the immense potential. Incubators and accelerators play a vital role in nurturing these nascent ventures, providing mentorship, resources, and crucial early-stage funding.
#
# **D. Massive Digital Adoption & Data Availability:** The "Jio effect" dramatically increased internet penetration and smartphone usage, creating a truly digital-first consumer base. Public digital infrastructure like Aadhaar (unique identity) and UPI (unified payments interface) have generated vast, invaluable datasets, providing the fuel for AI algorithms. This widespread digital adoption not only drives demand for AI-powered solutions but also offers an unparalleled opportunity for data-driven innovation.
#
# **E. Global Tech Giants & R&D Centers:** Recognizing India's strategic importance, major international tech companies like Google, Microsoft, IBM, and Amazon have established significant AI research and development centers in the country. These centers not only contribute to global AI advancements but also foster collaboration with Indian universities and startups, further integrating India into the global AI research landscape.
#
# ## AI in Action: Key Sectors & Applications
#
# AI is not just a concept in India; it's a practical tool being deployed across diverse sectors, yielding transformative results and addressing some of the nation's most pressing challenges.
#
# **A. Healthcare:** AI is revolutionizing Indian healthcare, particularly in diagnostics where access to specialists is limited. AI-powered tools are improving the accuracy and speed of radiology and pathology diagnoses, for instance, enabling early detection of conditions like diabetic retinopathy. Beyond diagnostics, AI is aiding in drug discovery, personalizing medicine, and enhancing telemedicine platforms, making healthcare more accessible and efficient.
#
# **B. Finance & Banking (FinTech):** The FinTech sector is a prime adopter of AI. Indian banks and financial institutions leverage AI for sophisticated fraud detection and risk assessment, securing transactions and minimizing losses. Personalized banking services, AI-driven credit scoring for underserved populations, algorithmic trading, and intelligent chatbots for 24/7 customer service are becoming standard, enhancing customer experience and operational efficiency.
#
# **C. Agriculture (AgriTech):** With a large agrarian economy, AI's impact on agriculture is profound. AI models predict crop yields, detect pests and diseases early, and provide hyper-local weather forecasting, enabling precision farming. AI-powered drones monitor crop health, optimizing irrigation and fertilizer use, thereby improving productivity and farmer livelihoods.
#
# **D. Education (EdTech):** AI is personalizing learning experiences in India's vast education sector. Adaptive learning platforms create tailored paths for students, automated grading provides instant feedback, and intelligent tutoring systems offer personalized support, making education more engaging and effective for a diverse student body.
#
# **E. E-commerce & Retail:** From personalized product recommendations that enhance customer experience to optimizing complex supply chains and inventory management, AI is at the core of India's booming e-commerce and retail sectors. Chatbots and virtual assistants handle customer queries, further streamlining operations.
#
# **F. Public Services & Governance:** AI is instrumental in India's "Smart Cities" initiatives, optimizing public transport and traffic management. It aids in disaster management, resource allocation during crises, and improving the efficiency of various government services, promising more responsive and citizen-centric governance.
#
# **G. Unique Indian Innovations:** What sets India apart is its focus on developing AI solutions tailored to its unique context. This includes a strong emphasis on multilingual AI and voice interfaces to bridge linguistic diversity, making technology accessible to a broader population. Furthermore, significant efforts are directed towards developing AI solutions for "Bharat" – rural and semi-urban India – addressing problems specific to these underserved communities, from financial inclusion to agricultural productivity.
#
# ## Challenges and Considerations
#
# While India's AI trajectory is promising, several challenges need careful navigation to ensure sustainable and equitable growth.
#
# **A. Data Privacy and Security:** The immense volume of data being generated by India's digital economy necessitates robust frameworks for data privacy and security. Ensuring responsible handling, storage, and utilization of personal data is paramount to building public trust and complying with global standards.
#
# **B. Ethical AI and Bias:** As AI systems become more prevalent, addressing algorithmic bias, ensuring fairness, and maintaining transparency are critical. India must proactively develop guidelines and best practices to prevent AI from perpetuating or amplifying existing societal inequalities.
#
# **C. Job Displacement and Reskilling:** The automation brought by AI will inevitably lead to job displacement in certain sectors. A massive national effort in workforce retraining and upskilling is essential to equip the Indian workforce with the skills needed for the evolving job market, fostering adaptability rather than fear.
#
# **D. Infrastructure Gaps:** Despite significant progress, bridging the digital divide in rural areas remains a challenge. Ensuring equitable access to high-speed internet and adequate computing power across the nation is crucial for widespread AI adoption and innovation.
#
# **E. Funding for Deep Tech Research:** While application-oriented AI thrives, there's a need to encourage more investment in fundamental AI research and deep tech. This will foster groundbreaking innovations and position India at the forefront of global AI advancements, not just as an implementer.
#
# **F. Regulatory Framework:** Developing a comprehensive and agile regulatory framework that fosters innovation while ensuring safety, accountability, and ethical deployment of AI systems is a complex but necessary task. Striking the right balance will be key to unlocking AI's full potential responsibly.
#
# ## The Road Ahead: India's AI Future
#
# India's vision for its AI future is ambitious and multifaceted, aiming to solidify its position as a global leader in the field.
#
# **A. Global AI Hub Potential:** With its talent, data, and burgeoning ecosystem, India is poised to become a world leader in AI innovation and deployment, attracting further international investment and collaboration.
#
# **B. Focus on Responsible AI:** A key pillar of India's strategy is the emphasis on responsible AI development and deployment. The nation is committed to ensuring that AI serves societal good, adheres to ethical principles, and contributes to inclusive growth.
#
# **C. Continued Investment:** Sustained investment in R&D, advanced skill development, and cross-sector collaboration will be crucial. This includes fostering public-private partnerships and creating an environment where cutting-edge research can flourish and translate into real-world applications.
#
# **D. Impact on Economy and Society:** AI is expected to be a significant driver of economic growth, improving productivity across industries, creating new job opportunities, and enhancing public services. Its transformative potential can lead to a better quality of life for millions, from improved healthcare outcomes to more efficient governance.
#
# **E. International Collaborations:** India recognizes the importance of partnerships with global AI leaders, research institutions, and international organizations. Such collaborations will facilitate knowledge exchange, accelerate research, and contribute to the development of global AI standards and best practices.
#
# ## Conclusion
#
# India's AI journey is nothing short of remarkable. From robust government backing and a formidable talent pool to a thriving startup ecosystem and vast digital adoption, the nation is harnessing the power of artificial intelligence to address its unique challenges and unlock unprecedented opportunities. While navigating critical considerations like data privacy, ethical deployment, and job transitions, India's commitment to "AI for All" underscores its ambition for inclusive growth. As India continues to innovate and integrate AI across its vast and diverse landscape, its journey promises not only to redefine its own future but also to offer a compelling blueprint for how emerging economies can responsibly harness the power of artificial intelligence for collective prosperity.
#
# What are your thoughts on India's AI trajectory? Share your insights in the comments below!
